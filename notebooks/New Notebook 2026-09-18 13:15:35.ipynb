# %%
# %sh
git status

# %%
# %sh
git add README.md 01_proyecto_bronze_completo.ipynb validaciones.ipynb

# %%
# %sh
git commit -m "Validaciones de calidad + README del proyecto"

# %%
# %sh
git push origin main
