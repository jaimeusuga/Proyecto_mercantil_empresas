# %%
# %sql

-- Crear el schema "Bronze" dentro del catalogo "workspace"

CREATE SCHEMA IF NOT EXISTS workspace.bronze
COMMENT 'Capa Bronze: Datos crudos sin transformar del proyecto Registro Mercantil';

# %%
# %sql
-- Ver todos los schemas en el catálogo "workspace"
SHOW SCHEMAS IN workspace;

# %%
# %sql
-- Ver detalles del schema bronze
DESCRIBE SCHEMA workspace.bronze;
